# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_json('states_daily.json')

# %%
dataset.shape
# Out:
# (192, 40)

# %%
dataset.head()
# Out:
#    an  ap  ar  as  br  ch  ct       date  dd  dl  ...  rj  sk     status  tg  \
# 0   0   1   0   0   0   0   0 2020-03-14   0   7  ...   3   0  Confirmed   1
# 1   0   0   0   0   0   0   0 2020-03-14   0   1  ...   1   0  Recovered   0
# 2   0   0   0   0   0   0   0 2020-03-14   0   1  ...   0   0   Deceased   0
# 3   0   0   0   0   0   0   0 2020-03-15   0   0  ...   1   0  Confirmed   2
# 4   0   0   0   0   0   0   0 2020-03-15   0   1  ...   2   0  Recovered   1
#
#    tn  tr  tt  up  ut  wb
# 0   1   0  81  12   0   0
# 1   0   0   9   4   0   0
# 2   0   0   2   0   0   0
# 3   0   0  27   1   0   0
# 4   0   0   4   0   0   0
#
# [5 rows x 40 columns]

# %%
dataset.columns
# Out:
# Index(['an', 'ap', 'ar', 'as', 'br', 'ch', 'ct', 'date', 'dd', 'dl', 'dn',
#        'ga', 'gj', 'hp', 'hr', 'jh', 'jk', 'ka', 'kl', 'la', 'ld', 'mh', 'ml',
#        'mn', 'mp', 'mz', 'nl', 'or', 'pb', 'py', 'rj', 'sk', 'status', 'tg',
#        'tn', 'tr', 'tt', 'up', 'ut', 'wb'],
#       dtype='object')

# %%
dataset['date'] = pd.to_datetime(dataset['date'])

# %%
plt.barh(dataset['status'], dataset['mh'])
# Out:
# <BarContainer object of 192 artists>

# %%
plt.figure(figsize=(10,6))
plt.barh(dataset['status'], dataset['dl'])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot_date(dataset['date'], dataset['dl'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(dataset['date'], dataset['dl'])
plt.xticks(rotation='vertical')
plt.show()

# %%
confirmed = dataset[dataset['status'] == 'Confirmed']
recovered = dataset[dataset['status'] == 'Recovered']

# %%
plt.figure(figsize=(10,6))
plt.plot(confirmed['date'], confirmed['dl'])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(confirmed['date'], confirmed['mh'],label = 'MH')
plt.plot(confirmed['date'], confirmed['dl'], label = 'DL')
plt.xticks(rotation='vertical')
plt.legend()
plt.title('COVID-19 Cases in Maharastra and Delhi')
plt.show()
